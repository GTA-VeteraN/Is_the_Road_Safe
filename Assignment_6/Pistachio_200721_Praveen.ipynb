# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
train_files = glob.glob('./*/**')

# %%
len(train_files)
# Out:
# 2148

# %%
import random
from random import shuffle
shuffle(train_files)

# %%
np.array(Image.open(train_files[0])).shape
# Out:
# (600, 600, 3)

# %%
x_train = np.zeros((2148,224,224,3))
y_train = np.zeros((2148,1))
# 0 for Kirmizi , 1 for Siirt

# %%
for i in range(len(train_files)):
    firstLetter = train_files[i].split('\\')[1][0]
    if(firstLetter=='S'): y_train[i]=1
    else: y_train[i]=0
    original = Image.open(train_files[i])
    resized = original.resize((224,224),0)
    x_train[i,:,:,:] = resized
x_train=x_train/255.0

# %%
plt.figure(figsize=(15,20))
for i in range(0,16):
    temp = random.randint(0,len(train_files))
    plt.subplot(4,4,i+1)
    plt.imshow(x_train[temp])
    plt.title(y_train[temp])
    plt.xlabel(train_files[temp].split('\\')[1].split('_')[0])
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
x_train[0].shape
# Out:
# (224, 224, 3)

# %%
def Inception_block(input_layer, f_path1, f_path2_conv3x3, f_path2_conv1x1, f_path3_conv1x1, f_path3_conv5x5, f_path4): 

  path1 = tf.keras.layers.Conv2D(filters=f_path1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)

  path2 = tf.keras.layers.Conv2D(filters = f_path2_conv1x1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path2 = tf.keras.layers.Conv2D(filters = f_path2_conv3x3, kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  path3 = tf.keras.layers.Conv2D(filters = f_path3_conv1x1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path3 = tf.keras.layers.Conv2D(filters = f_path3_conv5x5, kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  path4 = tf.keras.layers.MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input_layer)
  path4 = tf.keras.layers.Conv2D(filters = f_path4, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = tf.keras.layers.Concatenate(axis = -1)([path1, path2, path3, path4])

  return output_layer

# %%
def GoogLeNet():
  # input layer 
  input_layer = tf.keras.layers.Input(shape = (224, 224, 3))

  # convolutional layer -7x7 + 2S
  X = tf.keras.layers.Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

  # max-pooling layer - 3x3 +2S
  X = tf.keras.layers.MaxPooling2D(pool_size = (3,3), strides = 2)(X)
  #No LocalRespNorm
  # convolutional layer - 1x1 +1V
  X = tf.keras.layers.Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer - 1x1 +1S
  X = tf.keras.layers.Conv2D(filters = 192, kernel_size = (3,3), strides=1,padding = 'same', activation = 'relu')(X)
  #No LocalRespNorm
  # max-pooling layer - 
  X = tf.keras.layers.MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # Inception block - 3a
  X = Inception_block(X, 64,  96, 128, 16, 32, 32)

  # Inception block - 3b
  X = Inception_block(X, 128, 128, 192, 32, 96, 64)

  # max-pooling layer - 3x3 +2S
  X = tf.keras.layers.MaxPooling2D(pool_size= (3,3), strides = 2)(X)
    
  # Inception block - 4a
  X = Inception_block(X, 192, 96, 208, 16, 48, 64)

  # Extra network - AveragePool -> convolutional layer - 1x1 +1s -> Fully Connected Layer 1024 -> Dropout 0.7 -> Softmax layer
  X1 = tf.keras.layers.AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X1 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
  X1 = tf.keras.layers.Flatten()(X1)
  X1 = tf.keras.layers.Dense(1024, activation = 'relu')(X1)
  X1 = tf.keras.layers.Dropout(0.7)(X1)
  X1 = tf.keras.layers.Dense(2, activation = 'softmax')(X1)

  # Inception block - 4b
  X = Inception_block(X, 160, 112, 224, 24, 64, 64)

  # Inception block - 4c
  X = Inception_block(X, 128, 128, 256, 24, 64, 64)

  # Inception block - 4d
  X = Inception_block(X, 112, 144, 288, 32, 64, 64)

  # Extra network - AveragePool -> convolutional layer - 1x1 +1s -> Fully Connected Layer 1024 -> Dropout 0.7 -> Softmax layer
  X2 = tf.keras.layers.AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X2 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
  X2 = tf.keras.layers.Flatten()(X2)
  X2 = tf.keras.layers.Dense(1024, activation = 'relu')(X2)
  X2 = tf.keras.layers.Dropout(0.7)(X2)
  X2 = tf.keras.layers.Dense(2, activation = 'softmax')(X2)
    
  # Inception block - 4e
  X = Inception_block(X, 256, 160, 320, 32, 128, 128)

  # max-pooling layer - 3x3 + 2S
  X = tf.keras.layers.MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # Inception block - 5a 
  X = Inception_block(X, 256, 160, 320, 32, 128, 128)

  # Inception block - 5b
  X = Inception_block(X, 384, 192, 384, 48, 128, 128)

  # avg pool - 7x7 + 1(V)
  X = tf.keras.layers.GlobalAveragePooling2D(name='GAPL')(X)

  # Dropoutlayer - 40% 
  X = tf.keras.layers.Dropout(0.4)(X)

  # output layer 
  X = tf.keras.layers.Dense(2, activation = 'softmax')(X)
  
  # model
  model = tf.keras.models.Model(input_layer, [X, X1, X2], name = 'GoogLeNet')

  return model

# %%
model = GoogLeNet()

# %%
model.summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 109, 109, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 54, 54, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 54, 54, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 26, 26, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 26, 26, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 26, 26, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 26, 26, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 26, 26, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 26, 26, 96)   110688      ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 26, 26, 32)   12832       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 26, 26, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 26, 26, 224)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 26, 26, 192)  43200       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 26, 26, 32)   7200        ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 224)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 26, 26, 128)  28800       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 26, 26, 128)  221312      ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 26, 26, 96)   76896       ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 26, 26, 64)   14400       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 26, 26, 416)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 416)  0          ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 208)  86736       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 12, 12, 16)   6672        ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 12, 12, 416)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 192)  80064       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 96)   179808      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 12, 12, 48)   19248       ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 12, 12, 64)   26688       ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 12, 12, 400)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 12, 12, 224)  89824       ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 12, 12, 24)   9624        ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 400)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 12, 12, 160)  64160       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 12, 12, 112)  225904      ['conv2d_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 12, 12, 64)   25664       ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 12, 12, 400)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 12, 256)  102656      ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 12, 12, 24)   9624        ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 400)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 12, 12, 128)  51328       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 128)  295040      ['conv2d_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 64)   25664       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 12, 12, 384)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 12, 12, 288)  110880      ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 12, 12, 32)   12320       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 12, 12, 384)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 12, 12, 112)  43120       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 144)  373392      ['conv2d_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 64)   51264       ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 64)   24640       ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 12, 12, 384)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 320)  123200      ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 32)   12320       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 12, 12, 384)  0          ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 256)  98560       ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 160)  460960      ['conv2d_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 128)  102528      ['conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 128)  49280       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 12, 12, 672)  0           ['conv2d_41[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 5, 5, 672)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 5, 5, 320)    215360      ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 5, 5, 32)     21536       ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 5, 5, 672)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 5, 5, 256)    172288      ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 5, 5, 160)    460960      ['conv2d_48[0][0]']
#  conv2d_51 (Conv2D)             (None, 5, 5, 128)    102528      ['conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 5, 5, 128)    86144       ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 5, 5, 672)    0           ['conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 5, 5, 384)    258432      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 5, 5, 48)     32304       ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 5, 5, 672)   0           ['concatenate_7[0][0]']
#  )
#
#  average_pooling2d (AveragePool  (None, 3, 3, 400)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 3, 3, 384)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  conv2d_53 (Conv2D)             (None, 5, 5, 384)    258432      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 5, 5, 192)    663744      ['conv2d_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 5, 5, 128)    153728      ['conv2d_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 5, 5, 128)    86144       ['max_pooling2d_12[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 3, 3, 128)    51328       ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 3, 3, 128)    49280       ['average_pooling2d_1[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 5, 5, 832)    0           ['conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  flatten (Flatten)              (None, 1152)         0           ['conv2d_21[0][0]']
#
#  flatten_1 (Flatten)            (None, 1152)         0           ['conv2d_40[0][0]']
#
#  GAPL (GlobalAveragePooling2D)  (None, 832)          0           ['concatenate_8[0][0]']
#
#  dense (Dense)                  (None, 1024)         1180672     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 1024)         1180672     ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 832)          0           ['GAPL[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 2)            1666        ['dropout_2[0][0]']
#
#  dense_1 (Dense)                (None, 2)            2050        ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 2)            2050        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,503,478
# Trainable params: 8,503,478
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss=['sparse_categorical_crossentropy', 'sparse_categorical_crossentropy', 'sparse_categorical_crossentropy'], metrics=['accuracy'])

# %%
history = model.fit(x_train, [y_train,y_train,y_train],epochs=10)
# Out:
# Epoch 1/10
# 68/68 [==============================] - 216s 3s/step - loss: 2.4778 - dense_4_loss: 1.0068 - dense_1_loss: 0.7073 - dense_3_loss: 0.7637 - dense_4_accuracy: 0.5712 - dense_1_accuracy: 0.5838 - dense_3_accuracy: 0.5601
# Epoch 2/10
# 68/68 [==============================] - 201s 3s/step - loss: 1.9920 - dense_4_loss: 0.7230 - dense_1_loss: 0.6142 - dense_3_loss: 0.6548 - dense_4_accuracy: 0.5889 - dense_1_accuracy: 0.6536 - dense_3_accuracy: 0.6173
# Epoch 3/10
# 68/68 [==============================] - 194s 3s/step - loss: 1.5648 - dense_4_loss: 0.5580 - dense_1_loss: 0.4972 - dense_3_loss: 0.5096 - dense_4_accuracy: 0.7584 - dense_1_accuracy: 0.7686 - dense_3_accuracy: 0.7714
# Epoch 4/10
# 68/68 [==============================] - 194s 3s/step - loss: 1.3820 - dense_4_loss: 0.5038 - dense_1_loss: 0.4202 - dense_3_loss: 0.4580 - dense_4_accuracy: 0.7770 - dense_1_accuracy: 0.8096 - dense_3_accuracy: 0.7919
# Epoch 5/10
# 68/68 [==============================] - 199s 3s/step - loss: 1.3317 - dense_4_loss: 0.4891 - dense_1_loss: 0.4007 - dense_3_loss: 0.4419 - dense_4_accuracy: 0.7817 - dense_1_accuracy: 0.8119 - dense_3_accuracy: 0.7928
# Epoch 6/10
# 68/68 [==============================] - 196s 3s/step - loss: 1.1988 - dense_4_loss: 0.4267 - dense_1_loss: 0.3750 - dense_3_loss: 0.3970 - dense_4_accuracy: 0.8087 - dense_1_accuracy: 0.8324 - dense_3_accuracy: 0.8217
# Epoch 7/10
# 68/68 [==============================] - 194s 3s/step - loss: 1.1890 - dense_4_loss: 0.4244 - dense_1_loss: 0.3771 - dense_3_loss: 0.3875 - dense_4_accuracy: 0.8138 - dense_1_accuracy: 0.8357 - dense_3_accuracy: 0.8296
# Epoch 8/10
# 68/68 [==============================] - 193s 3s/step - loss: 1.1494 - dense_4_loss: 0.4047 - dense_1_loss: 0.3695 - dense_3_loss: 0.3752 - dense_4_accuracy: 0.8198 - dense_1_accuracy: 0.8305 - dense_3_accuracy: 0.8324
# Epoch 9/10
# 32/68 [=============>................] - ETA: 1:43 - loss: 1.0989 - dense_4_loss: 0.3848 - dense_1_loss: 0.3529 - dense_3_loss: 0.3612 - dense_4_accuracy: 0.8291 - dense_1_accuracy: 0.8408 - dense_3_accuracy: 0.8467
