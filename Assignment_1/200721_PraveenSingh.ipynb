# %% [markdown]
# ### Your task is to explain the functioning of each line in the following notebook an example is given

# %%
import tensorflow as tf  #this is used to import tensorflow for model creation and updating
import pandas as pd #this is used to import pandas library for data handling
import numpy as np # this is used to import numpy library for numerical computations involving matrix and vectors.

# %%
import keras # this is used to import keras for building deep learning models

# %%
import glob # this is used for importing glob used for searching all paths with some pattern.

# %%
train_files=glob.glob('C:/Users/india/Desktop/MTDS/*.jpg') #this is used to search for a path with some pattern using glob library,

# %%
train_files #Searching for all files in the directory C:/Users/india/Desktop/MTDS/* where (*.jpg)  specifies
# all the files in that directory with ending characters as .jpg
# Out:
# ['C:/Users/india/Desktop/MTDS\\download (1).jpg',
#  'C:/Users/india/Desktop/MTDS\\download.jpg',
#  'C:/Users/india/Desktop/MTDS\\photo-1597848212624-a19eb35e2651.jpg']

# %%
train_files[0] # taking the first result from the array of results.
# Out:
# 'C:/Users/india/Desktop/MTDS\\download (1).jpg'

# %%
import matplotlib.pyplot as plt #importing pyplot from matplotlib for plotting graphs.
from PIL import Image

# %%
img1=Image.open(train_files[0]) #Using Image.open() function for opening image of different image file extension.

# %%
img1 #Showing the stored image which is stored as PIL.JpegImagePlugin.JpegImageFile
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x1FDCEDE2790>

# %%
img1_array=np.array(img1) #storing the pixel values of image as a numpy array

# %%
print( img1_array.shape) #returns the shape of numpy matrix - (194,259,3) => (194x259) size with 3 each values denoting RGB values.
print(img1_array) # returns the pixel value of the image.
# Out:
# (194, 259, 3)
# [[[148 199 244]
#   [148 199 244]
#   [148 199 246]
#   ...
#   [247 209   4]
#   [249 208   4]
#   [250 209   5]]
#
#  [[154 203 246]
#   [154 203 246]
#   [153 201 247]
#   ...
#   [253 214  12]
#   [255 215   5]
#   [255 216   6]]
#
#  [[160 207 249]
#   [160 207 249]
#   [160 207 251]
#   ...
#   [255 218  17]
#   [255 222   0]
#   [255 221   0]]
#
#  ...
#
#  [[ 74 114   0]
#   [ 99 139   0]
#   [151 192  25]
#   ...
#   [ 76  95   0]
#   [ 79  95   0]
#   [ 81  97   0]]
#
#  [[ 71 110   0]
#   [ 81 118   0]
#   [120 155   9]
#   ...
#   [ 94 115  14]
#   [ 70  94   0]
#   [ 53  77   0]]
#
#  [[ 86 125  10]
#   [ 86 124   2]
#   [113 146  13]
#   ...
#   [ 88 108   9]
#   [ 61  89   2]
#   [ 44  71   0]]]
